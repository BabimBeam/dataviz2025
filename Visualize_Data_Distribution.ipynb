# %% [markdown]
# <a href="https://colab.research.google.com/github/BabimBeam/dataviz2025/blob/main/Visualize_Data_Distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # การแสดงผลการกระจายของข้อมูล

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path_to_stopandsearch = '/content/drive/MyDrive/Python&DataViz2025/2025-01/2025-01-bedfordshire-stop-and-search.csv'

# %%
stopandsearch_df = pd.read_csv(path_to_stopandsearch)
stopandsearch_df
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# 2                           False                 NaN  52.132059  -0.296600
# 3                           False                 NaN  52.132059  -0.296600
# 4                           False                 NaN  52.132059  -0.296600
# ..                            ...                 ...        ...        ...
# 382                         False                 NaN  52.134841  -0.483243
# 383                         False                 NaN  52.134841  -0.483243
# 384                         False                 NaN  51.881800  -0.368669
# 385                         False                 NaN  51.878459  -0.422384
# 386                         False                 NaN  51.878459  -0.422384
#
#      Gender Age range                             Self-defined ethnicity  \
# 0      Male     25-34  Mixed/Multiple ethnic groups - Any other Mixed...
# 1      Male     10-17  White - English/Welsh/Scottish/Northern Irish/...
# 2      Male     10-17  White - English/Welsh/Scottish/Northern Irish/...
# 3    Female     10-17  White - English/Welsh/Scottish/Northern Irish/...
# 4      Male     10-17  White - English/Welsh/Scottish/Northern Irish/...
# ..      ...       ...                                                ...
# 382  Female   over 34  White - English/Welsh/Scottish/Northern Irish/...
# 383    Male     25-34  White - English/Welsh/Scottish/Northern Irish/...
# 384    Male   over 34                    Other ethnic group - Not stated
# 385     NaN     18-24   Asian/Asian British - Any other Asian background
# 386    Male     18-24   Asian/Asian British - Any other Asian background
#
#     Officer-defined ethnicity  \
# 0                       Other
# 1                       White
# 2                       White
# 3                       White
# 4                       White
# ..                        ...
# 382                     White
# 383                     White
# 384                     White
# 385                     Asian
# 386                     Asian
#
#                                            Legislation  \
# 0    Police and Criminal Evidence Act 1984 (section 1)
# 1    Police and Criminal Evidence Act 1984 (section 1)
# 2    Police and Criminal Evidence Act 1984 (section 1)
# 3    Police and Criminal Evidence Act 1984 (section 1)
# 4    Police and Criminal Evidence Act 1984 (section 1)
# ..                                                 ...
# 382  Police and Criminal Evidence Act 1984 (section 1)
# 383  Police and Criminal Evidence Act 1984 (section 1)
# 384  Police and Criminal Evidence Act 1984 (section 1)
# 385              Misuse of Drugs Act 1971 (section 23)
# 386              Misuse of Drugs Act 1971 (section 23)
#
#              Object of search                       Outcome  \
# 0           Offensive weapons                        Arrest
# 1           Offensive weapons  A no further action disposal
# 2           Offensive weapons  A no further action disposal
# 3           Offensive weapons  A no further action disposal
# 4           Offensive weapons  A no further action disposal
# ..                        ...                           ...
# 382  Article for use in theft  A no further action disposal
# 383  Article for use in theft  A no further action disposal
# 384  Article for use in theft          Community resolution
# 385          Controlled drugs  A no further action disposal
# 386          Controlled drugs  A no further action disposal
#
#     Outcome linked to object of search  \
# 0                                False
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ..                                 ...
# 382                                NaN
# 383                                NaN
# 384                               True
# 385                                NaN
# 386                                NaN
#
#      Removal of more than just outer clothing
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# ..                                        ...
# 382                                     False
# 383                                     False
# 384                                     False
# 385                                     False
# 386                                     False
#
# [387 rows x 15 columns]

# %% [markdown]
# แปลงค่า Gender และ Age range เป็นจำนวนจริง

# %%
stopandsearch_df.groupby('Gender').count()
# Out:
#         Type  Date  Part of a policing operation  Policing operation  \
# Gender
# Female    40    40                            40                   0
# Male     287   287                           287                   0
#
#         Latitude  Longitude  Age range  Self-defined ethnicity  \
# Gender
# Female        34         34         40                      39
# Male         240        240        278                     280
#
#         Officer-defined ethnicity  Legislation  Object of search  Outcome  \
# Gender
# Female                         37           40                40       40
# Male                          276          287               287      287
#
#         Outcome linked to object of search  \
# Gender
# Female                                  10
# Male                                   107
#
#         Removal of more than just outer clothing
# Gender
# Female                                        40
# Male                                         287

# %%
stopandsearch_df.groupby('Age range').count()
# Out:
#            Type  Date  Part of a policing operation  Policing operation  \
# Age range
# 10-17        45    45                            45                   0
# 18-24        99    99                            99                   0
# 25-34        80    80                            80                   0
# over 34     126   126                           126                   0
# under 10      1     1                             1                   0
#
#            Latitude  Longitude  Gender  Self-defined ethnicity  \
# Age range
# 10-17            39         39      43                      42
# 18-24            84         84      84                      96
# 25-34            63         63      71                      79
# over 34         104        104     119                     122
# under 10          1          1       1                       1
#
#            Officer-defined ethnicity  Legislation  Object of search  Outcome  \
# Age range
# 10-17                             42           45                45       45
# 18-24                             97           99                99       99
# 25-34                             75           80                80       80
# over 34                          122          126               126      126
# under 10                           1            1                 1        1
#
#            Outcome linked to object of search  \
# Age range
# 10-17                                      17
# 18-24                                      41
# 25-34                                      32
# over 34                                    40
# under 10                                    0
#
#            Removal of more than just outer clothing
# Age range
# 10-17                                            45
# 18-24                                            99
# 25-34                                            80
# over 34                                         126
# under 10                                          1

# %%
df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
stopandsearch_df.shape
# Out:
# (387, 15)

# %%
stopandsearch_df_dropna = stopandsearch_df.dropna(subset=['Age range','Gender'])

# %%
stopandsearch_df_dropna['Gender'] = stopandsearch_df_dropna['Gender'].replace({'Male':35,'Female':1})
stopandsearch_df_dropna['Age range'] = stopandsearch_df_dropna['Age range'].replace({'under 10' : 10 ,'over 34': 34,
                                                                                     '25-34':30, '18-24': 21, '10-17':14})
# Out:
# /tmp/ipython-input-2654535151.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stopandsearch_df_dropna['Gender'] = stopandsearch_df_dropna['Gender'].replace({'Male':35,'Female':1})
# /tmp/ipython-input-2654535151.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopandsearch_df_dropna['Gender'] = stopandsearch_df_dropna['Gender'].replace({'Male':35,'Female':1})
# /tmp/ipython-input-2654535151.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stopandsearch_df_dropna['Age range'] = stopandsearch_df_dropna['Age range'].replace({'under 10' : 10 ,'over 34': 34,
# /tmp/ipython-input-2654535151.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopandsearch_df_dropna['Age range'] = stopandsearch_df_dropna['Age range'].replace({'under 10' : 10 ,'over 34': 34,

# %%
pd.plotting.parallel_coordinates(stopandsearch_df_dropna, ('Gender', 'Age range', 'Self-defined ethnicity'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Gender', 'Age range', 'Self-defined ethnicity')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2002483501.py in <cell line: 0>()
# ----> 1 pd.plotting.parallel_coordinates(stopandsearch_df_dropna, ('Gender', 'Age range', 'Self-defined ethnicity'))
#
# /usr/local/lib/python3.12/dist-packages/pandas/plotting/_misc.py in parallel_coordinates(frame, class_column, cols, ax, color, use_columns, xticks, colormap, axvlines, axvlines_kwds, sort_labels, **kwargs)
#     511     """
#     512     plot_backend = _get_plot_backend("matplotlib")
# --> 513     return plot_backend.parallel_coordinates(
#     514         frame=frame,
#     515         class_column=class_column,
#
# /usr/local/lib/python3.12/dist-packages/pandas/plotting/_matplotlib/misc.py in parallel_coordinates(frame, class_column, cols, ax, color, use_columns, xticks, colormap, axvlines, axvlines_kwds, sort_labels, **kwds)
#     364
#     365     n = len(frame)
# --> 366     classes = frame[class_column].drop_duplicates()
#     367     class_col = frame[class_column]
#     368
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: ('Gender', 'Age range', 'Self-defined ethnicity')

# %% [markdown]
# #Scatter plot

# %%
import numpy as np

# %% [markdown]
# ## เปลี่ยนความโปร่งใสเพื่อดูข้อมูลที่ทับกัน

# %%
plt.scatter(stopandsearch_df_dropna['Age range'],stopandsearch_df_dropna['Gender'],alpha=0.5)

# %%
plt.hist(np.random.normal(loc=0, scale=0.1, size=len(stopandsearch_df_dropna)))
# Out:
# (array([ 6.,  3., 18., 43., 59., 72., 67., 32., 12.,  6.]),
#  array([-0.29746663, -0.24063554, -0.18380446, -0.12697337, -0.07014229,
#         -0.0133112 ,  0.04351988,  0.10035097,  0.15718206,  0.21401314,
#          0.27084423]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # สร้าง list ของ ตัวเลข random ที่เป็น normal distribution

# %%
stopandsearch_df_dropna['Gender'] = stopandsearch_df_dropna['Gender'] * np.random.normal(loc=1, scale=0.1, size=len(stopandsearch_df_dropna))
# Out:
# /tmp/ipython-input-2211325525.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopandsearch_df_dropna['Gender'] = stopandsearch_df_dropna['Gender'] * np.random.normal(loc=1, scale=0.1, size=len(stopandsearch_df_dropna))

# %%
stopandsearch_df_dropna['Age range'] = stopandsearch_df_dropna['Age range'] * np.random.normal(loc=1, scale=0.01, size=len(stopandsearch_df_dropna))
# Out:
# /tmp/ipython-input-2945934892.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopandsearch_df_dropna['Age range'] = stopandsearch_df_dropna['Age range'] * np.random.normal(loc=1, scale=0.01, size=len(stopandsearch_df_dropna))

# %%
np.random.normal(loc=1, scale=0.1, size=len(stopandsearch_df_dropna))
# Out:
# array([1.16397948, 1.02359505, 0.78352346, 0.90409977, 1.11372312,
#        1.11352011, 0.97121184, 1.01799086, 0.88497909, 0.83378555,
#        0.99538959, 1.07270601, 0.99651609, 0.85246763, 1.19249831,
#        0.8390933 , 1.08470881, 1.06208509, 0.86979625, 0.86774332,
#        1.00330579, 0.93743273, 1.0869169 , 0.86025472, 1.08029554,
#        0.88200224, 1.00673276, 0.91706223, 0.96730225, 1.13959856,
#        0.83688499, 0.81916315, 1.06642096, 0.8241965 , 0.92657481,
#        0.98289365, 0.9948618 , 1.05985234, 1.05302764, 0.85921889,
#        0.9239916 , 1.16272949, 0.94021553, 1.12874111, 1.05243802,
#        1.036893  , 1.14100429, 0.98123435, 0.93215172, 1.16637087,
#        0.97409355, 0.87481804, 0.82919788, 1.1106024 , 1.07507613,
#        1.0988148 , 1.02096724, 0.91155063, 1.04345118, 1.04194494,
#        0.89573036, 0.96334227, 0.82177148, 0.85596634, 0.91814117,
#        1.18853987, 1.09838673, 1.08894383, 1.10512557, 1.18161276,
#        0.84172052, 1.06276195, 1.05226136, 1.10850159, 0.96274052,
#        0.95218773, 0.96516463, 1.14731822, 1.12497656, 1.04202927,
#        0.81177675, 1.02134448, 0.82818308, 0.85789834, 1.0750008 ,
#        0.9244643 , 1.05538254, 1.13831928, 1.06112343, 1.05961116,
#        0.98453392, 1.02239037, 0.85984931, 1.10934245, 1.1966164 ,
#        0.97679549, 1.07245496, 0.93274571, 0.8341845 , 1.00977545,
#        1.10646706, 1.00369392, 0.8684476 , 1.05425668, 1.13496879,
#        0.79817521, 1.07294909, 0.93711188, 1.11936709, 1.01975961,
#        0.8789797 , 1.19078784, 0.8948449 , 0.97356952, 0.96040314,
#        1.05220114, 1.22361784, 0.9914316 , 1.16572202, 1.00304393,
#        0.95959146, 1.19433703, 1.0006518 , 0.9453275 , 0.99775434,
#        0.9033898 , 0.90787816, 1.00933132, 1.00396875, 1.00629219,
#        1.12563467, 1.01958269, 1.23905569, 0.95632302, 1.04796902,
#        0.90114754, 0.99876225, 1.07642004, 0.85671563, 1.02449919,
#        0.88962306, 1.06145371, 0.92342708, 1.01615668, 1.11586692,
#        0.88909956, 1.1290396 , 0.93757228, 0.95683179, 1.04959734,
#        0.94656568, 1.16984965, 0.95244164, 1.09198722, 0.95503345,
#        0.80094993, 0.91286692, 0.94337772, 1.05491865, 0.88069898,
#        1.13541148, 0.98555781, 0.99421887, 0.99852904, 0.98158405,
#        1.07500828, 1.10631641, 1.07924953, 1.03135833, 1.11580876,
#        0.92932302, 1.13551746, 1.03236906, 0.93632868, 1.19509612,
#        0.96411348, 0.88135169, 0.99231463, 1.01647375, 0.81081534,
#        0.97642879, 0.91257305, 0.75329747, 1.07063109, 0.97040633,
#        0.78865488, 1.02400255, 1.02462933, 0.98148881, 1.07547303,
#        1.06318812, 1.02624233, 1.07752479, 1.02329273, 0.92010557,
#        0.9616495 , 0.95633593, 1.04210085, 1.09697857, 1.21079804,
#        0.89834011, 1.1759022 , 1.10782927, 0.87300217, 1.0013441 ,
#        1.01269373, 0.9880187 , 1.07038669, 1.04025246, 1.2591814 ,
#        0.79264086, 1.08009324, 1.03456448, 1.04805676, 1.14756468,
#        0.92731264, 1.15269787, 0.92808279, 1.20790878, 1.0966649 ,
#        0.95844967, 1.09632443, 1.05346317, 0.96538341, 0.98197008,
#        0.99303134, 0.96315665, 0.8276263 , 0.74426223, 1.02755616,
#        1.03912565, 1.07202814, 1.02450628, 0.92520375, 1.00906419,
#        1.07638306, 0.98462467, 1.04775107, 1.07865672, 0.86529158,
#        0.97847678, 0.90389574, 1.07201366, 0.86776101, 0.94091746,
#        0.81743095, 0.92302391, 0.99537065, 1.03489377, 0.91794404,
#        1.24342486, 1.06181271, 1.05643186, 0.95112978, 1.10033286,
#        1.01989655, 1.03723072, 0.90612846, 1.0451265 , 0.9933205 ,
#        1.08936369, 1.16098279, 0.7511046 , 1.01942537, 0.95777195,
#        0.99090123, 0.83232768, 1.10644408, 0.77872977, 1.03300172,
#        1.06029314, 0.93966294, 0.90503366, 0.82284391, 1.02955238,
#        0.94420311, 1.04036893, 0.94259736, 1.02080077, 0.84467097,
#        1.1100857 , 0.92150749, 0.94313647, 0.87251935, 0.98678214,
#        1.05427293, 1.01399273, 0.84155482, 0.97094428, 0.85902117,
#        1.00257725, 1.03066648, 0.97200476, 0.97926755, 1.03114664,
#        1.17092872, 1.12067908, 1.04273031, 1.13256904, 0.94098328,
#        1.07680927, 0.98436062, 1.06019383, 1.02320873, 1.0787724 ,
#        0.94706965, 1.06402966, 1.0153379 , 1.0612332 , 1.06185889,
#        1.0035004 , 0.93113487, 1.07207491, 1.26832549, 0.98763076,
#        0.91985118, 1.00874004, 1.12795675])

# %%
list_of_rn = np.random.normal(loc=1, scale=0.1, size=len(stopandsearch_df_dropna))

# %%
plt.hist(list_of_rn);

# %%
hist_out = plt.hist(list_of_rn)

# %%
hist_out
# Out:
# (array([ 7., 24., 30., 61., 70., 54., 41., 21.,  7.,  3.]),
#  array([0.75198597, 0.80519579, 0.85840561, 0.91161543, 0.96482525,
#         1.01803507, 1.07124489, 1.12445471, 1.17766453, 1.23087435,
#         1.28408417]),
#  <BarContainer object of 10 artists>)

# %%
hist_out[0]
# Out:
# array([ 7., 24., 30., 61., 70., 54., 41., 21.,  7.,  3.])

# %%
hist_out = plt.hist(list_of_rn,bins=20)

# %%
stopandsearch_df_dropna['Gender'] = stopandsearch_df_dropna['Gender'] * list_of_rn
# Out:
# /tmp/ipython-input-864405060.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopandsearch_df_dropna['Gender'] = stopandsearch_df_dropna['Gender'] * list_of_rn

# %% [markdown]
# #ลบค่าที่เป็น Outliers

# %%
stopandsearch_df_dropna[(stopandsearch_df_dropna['Gender']>=0) & (stopandsearch_df_dropna['Gender']<=40)]
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 5                Person search  2025-01-01T10:00:00+00:00
# 7                Person search  2025-01-01T12:12:00+00:00
# ..                         ...                        ...
# 380              Person search  2025-01-31T21:00:00+00:00
# 381              Person search  2025-01-31T21:24:00+00:00
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# 3                           False                 NaN  52.132059  -0.296600
# 5                           False                 NaN  51.895904  -0.444082
# 7                           False                 NaN  52.133738  -0.465411
# ..                            ...                 ...        ...        ...
# 380                          True                 NaN  51.880756  -0.417974
# 381                         False                 NaN  52.134841  -0.483243
# 382                         False                 NaN  52.134841  -0.483243
# 383                         False                 NaN  52.134841  -0.483243
# 386                         False                 NaN  51.878459  -0.422384
#
#         Gender  Age range                             Self-defined ethnicity  \
# 0    34.366625  29.867536  Mixed/Multiple ethnic groups - Any other Mixed...
# 1    25.368139  13.988543  White - English/Welsh/Scottish/Northern Irish/...
# 3     0.908567  14.019397  White - English/Welsh/Scottish/Northern Irish/...
# 5    27.758281  29.531814                    Other ethnic group - Not stated
# 7    39.599379  34.147532  Black/African/Caribbean/Black British - Any ot...
# ..         ...        ...                                                ...
# 380  37.297368  33.804906  Black/African/Caribbean/Black British - Any ot...
# 381  27.179919  33.413384  Mixed/Multiple ethnic groups - White and Black...
# 382   1.026172  33.831026  White - English/Welsh/Scottish/Northern Irish/...
# 383  28.731147  30.524353  White - English/Welsh/Scottish/Northern Irish/...
# 386  30.191575  20.839464   Asian/Asian British - Any other Asian background
#
#     Officer-defined ethnicity  \
# 0                       Other
# 1                       White
# 3                       White
# 5                         NaN
# 7                       Black
# ..                        ...
# 380                     Black
# 381                     Black
# 382                     White
# 383                     White
# 386                     Asian
#
#                                            Legislation  \
# 0    Police and Criminal Evidence Act 1984 (section 1)
# 1    Police and Criminal Evidence Act 1984 (section 1)
# 3    Police and Criminal Evidence Act 1984 (section 1)
# 5                Misuse of Drugs Act 1971 (section 23)
# 7                Misuse of Drugs Act 1971 (section 23)
# ..                                                 ...
# 380              Misuse of Drugs Act 1971 (section 23)
# 381  Police and Criminal Evidence Act 1984 (section 1)
# 382  Police and Criminal Evidence Act 1984 (section 1)
# 383  Police and Criminal Evidence Act 1984 (section 1)
# 386              Misuse of Drugs Act 1971 (section 23)
#
#              Object of search                       Outcome  \
# 0           Offensive weapons                        Arrest
# 1           Offensive weapons  A no further action disposal
# 3           Offensive weapons  A no further action disposal
# 5            Controlled drugs  A no further action disposal
# 7            Controlled drugs  A no further action disposal
# ..                        ...                           ...
# 380          Controlled drugs  A no further action disposal
# 381  Article for use in theft  A no further action disposal
# 382  Article for use in theft  A no further action disposal
# 383  Article for use in theft  A no further action disposal
# 386          Controlled drugs  A no further action disposal
#
#     Outcome linked to object of search  \
# 0                                False
# 1                                  NaN
# 3                                  NaN
# 5                                  NaN
# 7                                  NaN
# ..                                 ...
# 380                                NaN
# 381                              False
# 382                                NaN
# 383                                NaN
# 386                                NaN
#
#      Removal of more than just outer clothing
# 0                                       False
# 1                                       False
# 3                                       False
# 5                                       False
# 7                                       False
# ..                                        ...
# 380                                     False
# 381                                     False
# 382                                     False
# 383                                     False
# 386                                     False
#
# [279 rows x 15 columns]

# %%
pd.plotting.parallel_coordinates(stopandsearch_df_dropna[['Gender', 'Age range', 'Self-defined ethnicity']],
                      'Self-defined ethnicity')
plt.legend(loc='lower center', bbox_to_anchor=(0.5, -1.2))
plt.show()

# %% [markdown]
# ## Scatter 2D

# %% [markdown]
# ## scatter - default

# %%
plt.scatter(df['PetalLength'],df['PetalWidth'])

# %% [markdown]
# ## เปลี่ยนสี

# %%
plt.scatter(stopandsearch_df_dropna['Age range'],stopandsearch_df_dropna['Gender'],c='g',alpha=0.3)

# %% [markdown]
# ### ใช้ค่าสีในการแสดงค่า column อื่น
#
# ตัวอย่าง column > Officer-defined ethnicity

# %%
stopandsearch_df_dropna.groupby('Officer-defined ethnicity').count()
# Out:
#                            Type  Date  Part of a policing operation  \
# Officer-defined ethnicity
# Asian                        72    72                            72
# Black                        50    50                            50
# Other                         8     8                             8
# White                       174   174                           174
#
#                            Policing operation  Latitude  Longitude  Gender  \
# Officer-defined ethnicity
# Asian                                       0        59         59      72
# Black                                       0        40         40      50
# Other                                       0         6          6       8
# White                                       0       149        149     174
#
#                            Age range  Self-defined ethnicity  Legislation  \
# Officer-defined ethnicity
# Asian                             72                      70           72
# Black                             50                      50           50
# Other                              8                       8            8
# White                            174                     168          174
#
#                            Object of search  Outcome  \
# Officer-defined ethnicity
# Asian                                    72       72
# Black                                    50       50
# Other                                     8        8
# White                                   174      174
#
#                            Outcome linked to object of search  \
# Officer-defined ethnicity
# Asian                                                      29
# Black                                                      21
# Other                                                       4
# White                                                      58
#
#                            Removal of more than just outer clothing
# Officer-defined ethnicity
# Asian                                                            72
# Black                                                            50
# Other                                                             8
# White                                                           174

# %% [markdown]
# แทนค่า string ด้วย ตัวเลข

# %%
stopandsearch_df_dropna['Officer-defined ethnicity'] = stopandsearch_df_dropna['Officer-defined ethnicity'].replace({
    'Black': 0,'Other':1 , 'Asian' : 2, 'White':3})
# Out:
# /tmp/ipython-input-2362581751.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   stopandsearch_df_dropna['Officer-defined ethnicity'] = stopandsearch_df_dropna['Officer-defined ethnicity'].replace({
# /tmp/ipython-input-2362581751.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopandsearch_df_dropna['Officer-defined ethnicity'] = stopandsearch_df_dropna['Officer-defined ethnicity'].replace({

# %%
plt.scatter(stopandsearch_df_dropna['Age range'],stopandsearch_df_dropna['Gender'],
            c=stopandsearch_df_dropna['Officer-defined ethnicity'],alpha=0.3)

# %%
plt.scatter(stopandsearch_df_dropna['Age range'],stopandsearch_df_dropna['Gender'],
            c=stopandsearch_df_dropna['Officer-defined ethnicity'],alpha=0.3)
plt.title('Distribution of Age vs Gender for Stop and Search (Bedford Jan 2025)')
plt.xlabel('Age range')
plt.ylabel('Gender'); #ใส่ ; เพื่อไม่เอา output ของผลลัพธ์

# %% [markdown]
# ##Plot-Legend

# %%
df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
df2 = df.copy()
df2['Name'] = df2['Name'].replace({'Iris-setosa': 0, 'Iris-versicolor': 1, 'Iris-virginica':2})
df2
# Out:
# /tmp/ipython-input-718818506.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df2['Name'] = df2['Name'].replace({'Iris-setosa': 0, 'Iris-versicolor': 1, 'Iris-virginica':2})
#      SepalLength  SepalWidth  PetalLength  PetalWidth  Name
# 0            5.1         3.5          1.4         0.2     0
# 1            4.9         3.0          1.4         0.2     0
# 2            4.7         3.2          1.3         0.2     0
# 3            4.6         3.1          1.5         0.2     0
# 4            5.0         3.6          1.4         0.2     0
# ..           ...         ...          ...         ...   ...
# 145          6.7         3.0          5.2         2.3     2
# 146          6.3         2.5          5.0         1.9     2
# 147          6.5         3.0          5.2         2.0     2
# 148          6.2         3.4          5.4         2.3     2
# 149          5.9         3.0          5.1         1.8     2
#
# [150 rows x 5 columns]

# %% [markdown]
# ### color

# %%
plt.scatter(df['PetalLength'],df['PetalWidth'],c='r')

# %% [markdown]
# ## ใส่สีให้แต่ละจุด

# %%
set(df['Name']) #ดูว่ามีค่าอะไรบ้าง
# Out:
# {'Iris-setosa', 'Iris-versicolor', 'Iris-virginica'}

# %%
df2 = df.replace({'Iris-setosa': 0, 'Iris-versicolor': 1, 'Iris-virginica':2})
df2
# Out:
# /tmp/ipython-input-490463255.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df2 = df.replace({'Iris-setosa': 0, 'Iris-versicolor': 1, 'Iris-virginica':2})
#      SepalLength  SepalWidth  PetalLength  PetalWidth  Name
# 0            5.1         3.5          1.4         0.2     0
# 1            4.9         3.0          1.4         0.2     0
# 2            4.7         3.2          1.3         0.2     0
# 3            4.6         3.1          1.5         0.2     0
# 4            5.0         3.6          1.4         0.2     0
# ..           ...         ...          ...         ...   ...
# 145          6.7         3.0          5.2         2.3     2
# 146          6.3         2.5          5.0         1.9     2
# 147          6.5         3.0          5.2         2.0     2
# 148          6.2         3.4          5.4         2.3     2
# 149          5.9         3.0          5.1         1.8     2
#
# [150 rows x 5 columns]

# %%
plt.scatter(df['PetalLength'],df['PetalWidth'],c=df2['Name'])

# %% [markdown]
# ### alpha กำหนดความโปร่งแสง

# %%
plt.scatter(df['PetalLength'],df['PetalWidth'],c=df2['Name'],alpha=0.5)

# %% [markdown]
# ## ใช้ขนาดของ marker แสดงค่าของ feature

# %%
plt.scatter(df['PetalLength'],df['SepalLength'],s=50*df['PetalWidth'],c=df2['Name'],alpha=0.5)

# %% [markdown]
# ## ตัวแปร Marker ใช้ในการเปลี่ยนหน้าตาของ marker

# %%
plt.scatter(df['PetalLength'],df['PetalWidth'],s=100,c=df2['Name'],alpha=0.5,marker='*')

# %% [markdown]
# ## การ plot กราฟหลายๆอันซ้อนกัน

# %%
plt.scatter(df['PetalLength'][:50],df['PetalWidth'][:50],s=100,c='m',alpha=0.5,marker='$S$')
plt.scatter(df['PetalLength'][50:100],df['PetalWidth'][50:100],s=100,c='c',alpha=0.5,marker='$E$')
plt.scatter(df['PetalLength'][100:],df['PetalWidth'][100:],s=100,c='r',alpha=0.5,marker='$I$')

# %% [markdown]
# ###Label-Legend

# %% [markdown]
# ```plt.plot()``` input  ตัวที่ 3 คือ ตัวกำหนดหน้าตาของ marker
#
# 'หน้าตาmarker'-'ลักษณะของเส้นเชื่อมจุด'-'สี'

# %%
plt.plot(df['PetalLength'][:50],df['PetalWidth'][:50],'or',alpha=0.5)

# %%
plt.plot(df['PetalLength'][:50],df['PetalWidth'][:50],'o-r',alpha=0.5)

# %%
plt.plot(df['PetalLength'][:50],df['PetalWidth'][:50],'o:r',alpha=0.5)

# %%
plt.plot(df['PetalLength'][:50],df['PetalWidth'][:50],'or',alpha=0.5,label='setosa')
plt.plot(df['PetalLength'][50:100],df['PetalWidth'][50:100],'xc',alpha=0.5,label='versicolor')
plt.plot(df['PetalLength'][100:],df['PetalWidth'][100:],'*m',alpha=0.5,label='virginica')
plt.legend()

# %% [markdown]
# ### การใส่ชื่อกราฟ และชื่อแกน

# %%
plt.plot(df['PetalLength'][:50],df['PetalWidth'][:50],'or',alpha=0.5,label='setosa')
plt.plot(df['PetalLength'][50:100],df['PetalWidth'][50:100],'xc',alpha=0.5,label='versicolor')
plt.plot(df['PetalLength'][100:],df['PetalWidth'][100:],'*m',alpha=0.5,label='virginica')
plt.legend(loc='lower right')
plt.title('Iris flower data distribution') ##ชื่อกราฟ
plt.xlabel('PetalLength') ##ชื่อแกน X
plt.ylabel('PetalWidth'); ##ชื่อแกน y

# %% [markdown]
# ### 3D scatter

# %%
ax = plt.axes(projection ="3d")
ax.scatter3D(df['PetalLength'],df['PetalWidth'],df['SepalWidth'],c=df2['Name'])

# %% [markdown]
# ## Bubble Chart
#
# Scatter plot ที่ใช้ขนาดของ marker ในการสื่อปริมาณของข้อมูล

# %%
plt.scatter(df['PetalLength'][:50],df['SepalLength'][:50],s=150*df['PetalWidth'][100:],c='r',alpha=0.5)

# %% [markdown]
# ### Example

# %% [markdown]
# ### Box-plot

# %%
df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
stopandsearch_df

# %%
O = plt.boxplot(stopandsearch_df['Latitude'].dropna(),whis=1,vert=False)

# %%
O
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x78d592a0b4d0>,
#   <matplotlib.lines.Line2D at 0x78d592a0b7d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x78d592a0baa0>,
#   <matplotlib.lines.Line2D at 0x78d592a0bda0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x78d592a0a2a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x78d5928e4080>],
#  'fliers': [<matplotlib.lines.Line2D at 0x78d5928e4380>],
#  'means': []}

# %%
O['fliers']

# %%
O['fliers'][0]

# %%
dir(O['fliers'][0])
# Out:
# ['_PROPERTIES_EXCLUDED_FROM_SET',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_agg_filter',
#  '_alias_map',
#  '_alpha',
#  '_animated',
#  '_antialiased',
#  '_axes',
#  '_callbacks',
#  '_clipon',
#  '_clippath',
#  '_cm_set',
#  '_color',
#  '_dash_pattern',
#  '_dashcapstyle',
#  '_dashjoinstyle',
#  '_different_canvas',
#  '_drawStyles_l',
#  '_drawStyles_s',
#  '_drawstyle',
#  '_fully_clipped_to_axes',
#  '_gapcolor',
#  '_get_markerfacecolor',
#  '_get_transformed_path',
#  '_gid',
#  '_in_layout',
#  '_internal_update',
#  '_invalidx',
#  '_invalidy',
#  '_label',
#  '_lineStyles',
#  '_linestyle',
#  '_linestyles',
#  '_linewidth',
#  '_marker',
#  '_markeredgecolor',
#  '_markeredgewidth',
#  '_markerfacecolor',
#  '_markerfacecoloralt',
#  '_markersize',
#  '_markevery',
#  '_mouseover',
#  '_parent_figure',
#  '_path',
#  '_path_effects',
#  '_picker',
#  '_pickradius',
#  '_rasterized',
#  '_remove_method',
#  '_set_alpha_for_array',
#  '_set_gc_clip',
#  '_set_markercolor',
#  '_sketch',
#  '_snap',
#  '_solidcapstyle',
#  '_solidjoinstyle',
#  '_stale',
#  '_sticky_edges',
#  '_subslice',
#  '_subslice_optim_min_size',
#  '_transform',
#  '_transformSet',
#  '_transform_path',
#  '_transformed_path',
#  '_unscaled_dash_pattern',
#  '_update_props',
#  '_update_set_signature_and_docstring',
#  '_url',
#  '_visible',
#  '_x',
#  '_x_filled',
#  '_xorig',
#  '_xy',
#  '_y',
#  '_yorig',
#  'add_callback',
#  'axes',
#  'clipbox',
#  'contains',
#  'convert_xunits',
#  'convert_yunits',
#  'draw',
#  'drawStyleKeys',
#  'drawStyles',
#  'figure',
#  'fillStyles',
#  'filled_markers',
#  'findobj',
#  'format_cursor_data',
#  'get_aa',
#  'get_agg_filter',
#  'get_alpha',
#  'get_animated',
#  'get_antialiased',
#  'get_bbox',
#  'get_c',
#  'get_children',
#  'get_clip_box',
#  'get_clip_on',
#  'get_clip_path',
#  'get_color',
#  'get_cursor_data',
#  'get_dash_capstyle',
#  'get_dash_joinstyle',
#  'get_data',
#  'get_drawstyle',
#  'get_ds',
#  'get_figure',
#  'get_fillstyle',
#  'get_gapcolor',
#  'get_gid',
#  'get_in_layout',
#  'get_label',
#  'get_linestyle',
#  'get_linewidth',
#  'get_ls',
#  'get_lw',
#  'get_marker',
#  'get_markeredgecolor',
#  'get_markeredgewidth',
#  'get_markerfacecolor',
#  'get_markerfacecoloralt',
#  'get_markersize',
#  'get_markevery',
#  'get_mec',
#  'get_mew',
#  'get_mfc',
#  'get_mfcalt',
#  'get_mouseover',
#  'get_ms',
#  'get_path',
#  'get_path_effects',
#  'get_picker',
#  'get_pickradius',
#  'get_rasterized',
#  'get_sketch_params',
#  'get_snap',
#  'get_solid_capstyle',
#  'get_solid_joinstyle',
#  'get_tightbbox',
#  'get_transform',
#  'get_transformed_clip_path_and_affine',
#  'get_url',
#  'get_visible',
#  'get_window_extent',
#  'get_xdata',
#  'get_xydata',
#  'get_ydata',
#  'get_zorder',
#  'have_units',
#  'ind_offset',
#  'is_dashed',
#  'is_transform_set',
#  'lineStyles',
#  'markers',
#  'mouseover',
#  'pchanged',
#  'pick',
#  'pickable',
#  'pickradius',
#  'properties',
#  'recache',
#  'recache_always',
#  'remove',
#  'remove_callback',
#  'set',
#  'set_aa',
#  'set_agg_filter',
#  'set_alpha',
#  'set_animated',
#  'set_antialiased',
#  'set_c',
#  'set_clip_box',
#  'set_clip_on',
#  'set_clip_path',
#  'set_color',
#  'set_dash_capstyle',
#  'set_dash_joinstyle',
#  'set_dashes',
#  'set_data',
#  'set_drawstyle',
#  'set_ds',
#  'set_figure',
#  'set_fillstyle',
#  'set_gapcolor',
#  'set_gid',
#  'set_in_layout',
#  'set_label',
#  'set_linestyle',
#  'set_linewidth',
#  'set_ls',
#  'set_lw',
#  'set_marker',
#  'set_markeredgecolor',
#  'set_markeredgewidth',
#  'set_markerfacecolor',
#  'set_markerfacecoloralt',
#  'set_markersize',
#  'set_markevery',
#  'set_mec',
#  'set_mew',
#  'set_mfc',
#  'set_mfcalt',
#  'set_mouseover',
#  'set_ms',
#  'set_path_effects',
#  'set_picker',
#  'set_pickradius',
#  'set_rasterized',
#  'set_sketch_params',
#  'set_snap',
#  'set_solid_capstyle',
#  'set_solid_joinstyle',
#  'set_transform',
#  'set_url',
#  'set_visible',
#  'set_xdata',
#  'set_ydata',
#  'set_zorder',
#  'stale',
#  'stale_callback',
#  'sticky_edges',
#  'update',
#  'update_from',
#  'zorder']

# %%
O['fliers'][0].get_xdata()
# Out:
# array([51.642262, 52.349993])

# %%
stopandsearch_df[(stopandsearch_df['Latitude']==O['fliers'][0].get_xdata()[0]) |
                  (stopandsearch_df['Latitude']==O['fliers'][0].get_xdata()[1])]
# Out:
#              Type                       Date  Part of a policing operation  \
# 53  Person search  2025-01-06T14:10:00+00:00                         False
# 80  Person search  2025-01-07T20:40:00+00:00                         False
#
#     Policing operation   Latitude  Longitude Gender Age range  \
# 53                 NaN  51.642262  -0.052279   Male     25-34
# 80                 NaN  52.349993  -0.178056   Male     10-17
#
#              Self-defined ethnicity Officer-defined ethnicity  \
# 53  Other ethnic group - Not stated                       NaN
# 80  Other ethnic group - Not stated                     Black
#
#                                           Legislation  \
# 53  Police and Criminal Evidence Act 1984 (section 1)
# 80  Police and Criminal Evidence Act 1984 (section 1)
#
#             Object of search                       Outcome  \
# 53         Offensive weapons  A no further action disposal
# 80  Article for use in theft  A no further action disposal
#
#    Outcome linked to object of search  \
# 53                                NaN
# 80                              False
#
#     Removal of more than just outer clothing
# 53                                     False
# 80                                     False

# %%
O['whiskers'][0].get_xdata()
# Out:
# array([51.879602, 51.685394])

# %%
O['caps'][0].get_xdata()
# Out:
# array([51.685394, 51.685394])

# %%
O = plt.boxplot(stopandsearch_df['Latitude'].dropna(),whis=1,vert=False)

# %%
O = plt.boxplot(stopandsearch_df['Latitude'].dropna(),whis=1,vert=False,showmeans=True,meanline=True)

# %%
O
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x78d59d666d20>,
#   <matplotlib.lines.Line2D at 0x78d59d667050>],
#  'caps': [<matplotlib.lines.Line2D at 0x78d59d667380>,
#   <matplotlib.lines.Line2D at 0x78d59d667590>],
#  'boxes': [<matplotlib.lines.Line2D at 0x78d59d666a20>],
#  'medians': [<matplotlib.lines.Line2D at 0x78d59d667710>],
#  'fliers': [<matplotlib.lines.Line2D at 0x78d59d667d40>],
#  'means': [<matplotlib.lines.Line2D at 0x78d59d667b90>]}

# %%
O = plt.boxplot(df['SepalWidth'],showmeans=True,meanline=True,vert=False)

# %% [markdown]
# #Subplot

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].boxplot(stopandsearch_df['Latitude'].dropna())
axes[0].set_title('Boxplot of Latitude')
axes[0].set_ylabel('Latitude')

axes[1].boxplot(stopandsearch_df['Longitude'].dropna())
axes[1].set_title('Boxplot of Longitude')
axes[1].set_ylabel('Longitude')

plt.tight_layout()
plt.show()

# %%
plt.subplot(1,2,1)
plt.boxplot(stopandsearch_df['Latitude'].dropna(),whis=1, vert=True, showmeans=True, meanline=True)
plt.title('Latitude')

plt.subplot(1,2,2)
plt.boxplot(stopandsearch_df['Longitude'].dropna(),whis=1, vert=True, showmeans=True, meanline=True)
plt.title('Longitude')
# Out:
# Text(0.5, 1.0, 'Longitude')

# %% [markdown]
# #Quiz 10

# %%
plt.subplot(2, 1, 1)
plt.boxplot(stopandsearch_df['Latitude'].dropna(), whis=1, vert=False, showmeans=True, meanline=True)
plt.title('BLatitude')

plt.subplot(2, 1, 2)
plt.boxplot(stopandsearch_df['Longitude'].dropna(), whis=1, vert=False, showmeans=True, meanline=True)
plt.title('Longitude')

plt.tight_layout()
plt.show()

# %% [markdown]
# # HW7 plot กราฟ แสดง การกระจายของข้อมูลใน india imdb และ มาพรีเซ็น เป็นกลุ่ม (2 กราฟ)
